# %%
# !git clone https://github.com/angel-one/smartapi-python.git
# Out:
# fatal: destination path 'smartapi-python' already exists and is not an empty directory.

# %%
pip install SmartApi
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd smartapi-python
# Out:
# /Users/dannyjadhav/smartapi-python

# %%
# !pip install -r requirements_dev.txt
# Out:
# ...
#   Using cached attrs-23.1.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached autobahn-23.6.2-py2.py3-none-any.whl
# ...
#   Using cached Automat-22.10.0-py2.py3-none-any.whl.metadata (1.0 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached certifi-2023.5.7-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached cffi-1.15.1.tar.gz (508 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached charset_normalizer-3.1.0-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached constantly-15.1.0-py2.py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached cryptography-43.0.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (5.4 kB)
# ...
#   Using cached hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached idna-3.4-py3-none-any.whl.metadata (9.8 kB)
# ...
#   Using cached incremental-22.10.0-py2.py3-none-any.whl.metadata (6.0 kB)
# ...

# %%
# !pip install pyotp
# !pip install websocket-client
# !pip install
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
pip install logzero
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from SmartApi import SmartConnect
import pyotp
import pandas as pd
import talib as ta
import numpy as np
import time
import json

from datetime import datetime, timedelta

# %%
API_KEY = "DPUfQ4dz"
CLIENT_ID = "D52359454"
PASSWORD = "1234"
TOTP_SECRET = "UALX2FAJSGYMFTKYHHYT4HC3IE"

# %%
from SmartApi import SmartConnect
import pyotp

# =========================
# CREDENTIALS
# =========================

API_KEY = "DPUfQ4dz"

CLIENT_ID = "D52359454"

PASSWORD = "1234"

TOTP_SECRET = "UALX2FAJSGYMFTKYHHYT4HC3IE"


# =========================
# GENERATE TOTP
# =========================

totp = pyotp.TOTP(TOTP_SECRET).now()

print("Generated TOTP:", totp)


# =========================
# INITIALIZE SMART API
# =========================

smartApi = SmartConnect(api_key=API_KEY)


# =========================
# LOGIN
# =========================

data = smartApi.generateSession(
    CLIENT_ID,
    PASSWORD,
    totp
)

print(data)


# =========================
# CHECK LOGIN STATUS
# =========================

if data["status"]:

    print("Login Successful")

    authToken = data['data']['jwtToken']

    refreshToken = data['data']['refreshToken']

    feedToken = smartApi.getfeedToken()

    print("JWT Token:", authToken)

    print("Feed Token:", feedToken)

else:

    print("Login Failed")
# Out:
# [I 260616 12:28:38 smartConnect:124] in pool
# Generated TOTP: 310969
# {'status': True, 'message': 'SUCCESS', 'errorcode': '', 'data': {'clientcode': 'D52359454', 'name': 'DNYANESHWAR SATISH JADHAV', 'email': '', 'mobileno': '', 'exchanges': ['nse_fo', 'nse_cm', 'cde_fo', 'ncx_fo', 'bse_fo', 'bse_cm', 'mcx_fo'], 'products': ['MARGIN', 'MIS', 'NRML', 'CNC', 'CO', 'BO'], 'lastlogintime': '', 'broker': '', 'jwtToken': 'Bearer eyJhbGciOiJIUzUxMiJ9.....pHyyTJok9jRf1V2HXN_rEIeLShKoDUn1vWHr6h2vYT33mIewCl33TNP-ntuPQMLQtoDcJxibXb24Fo9I0p1URw', 'refreshToken': 'eyJhbGciOiJIUzUxMiJ9.....Snsqe3gLNmbnTjs2FlmZPs_rVE38G2eIyrbHDOEChQKQRR3czC-FKtYPXt1eCAe02H9XsX1EFrhZNT3ID40Ndg', 'feedToken': 'eyJhbGciOiJIUzUxMiJ9.eyJ1c2VybmFtZSI6IkQ1MjM1OTQ1NCIsImlhdCI6MTc4MTU5MzExOSwiZXhwIjoxNzgxNjc5NTE5fQ.-5sZAT_X9CUJmyRK17xidP3zbp_GGhqSPF0qTeVi0vJcuzz41WnHgojFAJRe2lkNcTrAGsJeANC3D0zgLZ_0sg'}}
# Login Successful
# ...

# %%
from datetime import datetime, timedelta
import pandas as pd

def get_historical_data(
    smartApi,
    symboltoken,
    exchange="NSE",
    interval="FIVE_MINUTE",
    days=5
):

    try:

        # Current Time
        to_date = datetime.now()

        # Previous Days
        from_date = to_date - timedelta(days=days)

        # API Parameters
        historicParam = {

            "exchange": exchange,

            "symboltoken": str(symboltoken),

            "interval": interval,

            "fromdate": from_date.strftime("%Y-%m-%d %H:%M"),

            "todate": to_date.strftime("%Y-%m-%d %H:%M")
        }

        # Fetch Candle Data
        candles = smartApi.getCandleData(historicParam)

        # Check Status
        if not candles["status"]:

            print("Historical Data Error")

            return pd.DataFrame()

        # Convert to DataFrame
        df = pd.DataFrame(

            candles["data"],

            columns=[
                "datetime",
                "open",
                "high",
                "low",
                "close",
                "volume"
            ]
        )

        # Convert Datetime
        df["datetime"] = pd.to_datetime(df["datetime"])

        return df

    except Exception as e:

        print("Error:", e)

        return pd.DataFrame()

# %%
df = get_historical_data(

    smartApi=smartApi,

    symboltoken="25",

    exchange="NSE",

    interval="FIVE_MINUTE",

    days=900
)

print(df.head())
# Out:
#                    datetime    open    high     low   close  volume
# 0 2026-03-09 09:15:00+05:30  1985.0  1991.5  1940.4  1961.4  129068
# 1 2026-03-09 09:20:00+05:30  1962.7  1967.3  1951.0  1956.4   46127
# 2 2026-03-09 09:25:00+05:30  1956.5  1958.0  1945.4  1947.6   69730
# 3 2026-03-09 09:30:00+05:30  1947.7  1952.2  1945.0  1946.2   66701
# 4 2026-03-09 09:35:00+05:30  1946.2  1963.0  1941.1  1960.2   66245

# %%
df.shape
# Out:
# (4950, 6)

# %%
# ==========================================
# NIFTY 50 SYMBOL -> TOKEN MAPPING
# ==========================================

NIFTY_50_TICKERS = [

    "ADANIENT",
    "ADANIGAS",
    "ADANIGREEN",
    "ADANIPORTS",
    "ADANIPOWER",
    "ADANITRANS",
    "AXISBANK",
    "HAL",
    "HDFCBANK",
    "ICICIBANK",
    "TATAPOWER",
    "TATACOMM",
    "NTPC",
    "ONGC",
    "RELIANCE",
    "SBIN",
    "KOTAKBANK",
    "INFY",
    "BAJAJFINSV",
    "ITC",
    "MARUTI",
    "INDUSINDBK",
    "TATASTEEL",
    "BPCL",
    "HCLTECH",
    "HINDUNILVR",
    "WIPRO",
    "CANBK",
    "DLF",
    "LT",
    "TCS",
    "HDFCLIFE",
    "NCC"
]


TOKEN_MAPPING = {

    "ADANIENT": "25",

    "ADANIGAS": "6066",

    "ADANIGREEN": "3563",

    "ADANIPORTS": "15083",

    "ADANIPOWER": "17388",

    "ADANITRANS": "10217",

    "AXISBANK": "5900",

    "HAL": "2303",

    "HDFCBANK": "1333",

    "ICICIBANK": "4963",

    "TATAPOWER": "3426",

    "TATACOMM": "3721",

    "NTPC": "11630",

    "ONGC": "2475",

    "RELIANCE": "2885",

    "SBIN": "3045",

    "KOTAKBANK": "1922",

    "INFY": "1594",

    "BAJAJFINSV": "16675",

    "ITC": "1660",

    "MARUTI": "10999",

    "INDUSINDBK": "5258",

    "TATASTEEL": "3499",

    "BPCL": "526",

    "HCLTECH": "7229",

    "HINDUNILVR": "1394",

    "WIPRO": "3787",

    "CANBK": "10794",

    "DLF": "14732",

    "LT": "11483",

    "TCS": "11536",

    "HDFCLIFE": "467",

    "NCC": "2319"
}


# ==========================================
# CREATE SYMBOL -> TOKEN DATAFRAME
# ==========================================

import pandas as pd

mapping_df = pd.DataFrame({

    "Symbol": TOKEN_MAPPING.keys(),

    "Token": TOKEN_MAPPING.values()

})

print(mapping_df)
# Out:
#         Symbol  Token
# 0     ADANIENT     25
# 1     ADANIGAS   6066
# 2   ADANIGREEN   3563
# 3   ADANIPORTS  15083
# 4   ADANIPOWER  17388
# 5   ADANITRANS  10217
# 6     AXISBANK   5900
# 7          HAL   2303
# 8     HDFCBANK   1333
# 9    ICICIBANK   4963
# 10   TATAPOWER   3426
# 11    TATACOMM   3721
# 12        NTPC  11630
# 13        ONGC   2475
# 14    RELIANCE   2885
# 15        SBIN   3045
# 16   KOTAKBANK   1922
# 17        INFY   1594
# 18  BAJAJFINSV  16675
# 19         ITC   1660
# 20      MARUTI  10999
# 21  INDUSINDBK   5258
# 22   TATASTEEL   3499
# 23        BPCL    526
# 24     HCLTECH   7229
# 25  HINDUNILVR   1394
# 26       WIPRO   3787
# 27       CANBK  10794
# 28         DLF  14732
# 29          LT  11483
# 30         TCS  11536
# 31    HDFCLIFE    467
# 32         NCC   2319

# %%
symbol = "SBIN"

token = TOKEN_MAPPING[symbol]

print(token)
# Out:
# 3045

# %%
reverse_mapping = {

    v: k for k, v in TOKEN_MAPPING.items()

}

print(reverse_mapping["3045"])
# Out:
# SBIN

# %%
for symbol in NIFTY_50_TICKERS:

    token = TOKEN_MAPPING[symbol]

    print(symbol, token)
# Out:
# ADANIENT 25
# ADANIGAS 6066
# ADANIGREEN 3563
# ADANIPORTS 15083
# ADANIPOWER 17388
# ADANITRANS 10217
# AXISBANK 5900
# HAL 2303
# HDFCBANK 1333
# ICICIBANK 4963
# TATAPOWER 3426
# TATACOMM 3721
# NTPC 11630
# ONGC 2475
# RELIANCE 2885
# SBIN 3045
# KOTAKBANK 1922
# INFY 1594
# BAJAJFINSV 16675
# ITC 1660
# MARUTI 10999
# INDUSINDBK 5258
# TATASTEEL 3499
# BPCL 526
# HCLTECH 7229
# HINDUNILVR 1394
# WIPRO 3787
# CANBK 10794
# DLF 14732
# LT 11483
# TCS 11536
# HDFCLIFE 467
# NCC 2319

# %%
scanner_data = []

for symbol in NIFTY_50_TICKERS:

    scanner_data.append({

        "symbol": symbol,

        "token": TOKEN_MAPPING[symbol]

    })

print(scanner_data)
# Out:
# [{'symbol': 'ADANIENT', 'token': '25'}, {'symbol': 'ADANIGAS', 'token': '6066'}, {'symbol': 'ADANIGREEN', 'token': '3563'}, {'symbol': 'ADANIPORTS', 'token': '15083'}, {'symbol': 'ADANIPOWER', 'token': '17388'}, {'symbol': 'ADANITRANS', 'token': '10217'}, {'symbol': 'AXISBANK', 'token': '5900'}, {'symbol': 'HAL', 'token': '2303'}, {'symbol': 'HDFCBANK', 'token': '1333'}, {'symbol': 'ICICIBANK', 'token': '4963'}, {'symbol': 'TATAPOWER', 'token': '3426'}, {'symbol': 'TATACOMM', 'token': '3721'}, {'symbol': 'NTPC', 'token': '11630'}, {'symbol': 'ONGC', 'token': '2475'}, {'symbol': 'RELIANCE', 'token': '2885'}, {'symbol': 'SBIN', 'token': '3045'}, {'symbol': 'KOTAKBANK', 'token': '1922'}, {'symbol': 'INFY', 'token': '1594'}, {'symbol': 'BAJAJFINSV', 'token': '16675'}, {'symbol': 'ITC', 'token': '1660'}, {'symbol': 'MARUTI', 'token': '10999'}, {'symbol': 'INDUSINDBK', 'token': '5258'}, {'symbol': 'TATASTEEL', 'token': '3499'}, {'symbol': 'BPCL', 'token': '526'}, {'symbol': 'HCLTECH', 'tok
# ...
